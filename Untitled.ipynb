# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# %%
df = pd.read_csv('Service_Requests_Analysis.csv')
df.head()
# Out:
# C:\Users\Iman\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3251: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unique Key            Created Date       Closed Date Agency  \
# 0  32310363.0  12/31/2015 11:59:45 PM  01-01-2016 00:55   NYPD
# 1  32309934.0  12/31/2015 11:59:44 PM  01-01-2016 01:26   NYPD
# 2  32309159.0  12/31/2015 11:59:29 PM  01-01-2016 04:51   NYPD
# 3  32305098.0  12/31/2015 11:57:46 PM  01-01-2016 07:43   NYPD
# 4  32306529.0  12/31/2015 11:56:58 PM  01-01-2016 03:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# ...

# %%
df.isnull().sum()
# Out:
# Unique Key                             4
# Created Date                           4
# Closed Date                         2168
# Agency                                 4
# Agency Name                            4
# Complaint Type                         4
# Descriptor                          5918
# Location Type                        135
# Incident Zip                        2619
# Incident Address                   44414
# Street Name                        44414
# Cross Street 1                     49283
# Cross Street 2                     49783
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2819
# City                                2618
# Landmark                          300349
# Facility Type                       2175
# Status                                 4
# Due Date                               7
# Resolution Description                 4
# Resolution Action Updated Date      2191
# ...

# %%
df.drop(['School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Garage Lot Name'], axis = 1, inplace = True)

# %%
df2 = df.groupby('Agency')['Complaint Type'].value_counts().to_frame().rename(columns = {'Complaint Type' : 'Count'}).sort_values('Count', ascending = False)
df2.reset_index(inplace = True)
df2
# Out:
#    Agency             Complaint Type  Count
# 0    NYPD           Blocked Driveway  77043
# 1    NYPD            Illegal Parking  75361
# 2    NYPD    Noise - Street/Sidewalk  48612
# 3    NYPD         Noise - Commercial  35574
# 4    NYPD           Derelict Vehicle  17718
# 5    NYPD            Noise - Vehicle  17083
# 6    NYPD               Animal Abuse   7778
# 7    NYPD                    Traffic   4498
# 8    NYPD        Homeless Encampment   4416
# 9    NYPD               Noise - Park   4042
# 10   NYPD                    Vending   3802
# 11   NYPD                   Drinking   1280
# 12   NYPD   Noise - House of Worship    931
# 13   NYPD      Posting Advertisement    650
# 14   NYPD        Urinating in Public    592
# 15   NYPD  Bike/Roller/Skate Chronic    427
# 16   NYPD                Panhandling    307
# 17   NYPD           Disorderly Youth    286
# 18   NYPD          Illegal Fireworks    168
# 19   NYPD                   Graffiti    113
# ...

# %%
fig = plt.figure(figsize = (10,8))
plt.grid()
plt.barh(df2['Complaint Type'], df2['Count'], label = 'complaint count', color = 'red', edgecolor = 'black', 
            linewidth = 1.8, alpha = 0.8)

for i, v in enumerate(df2['Count']):
    plt.text(v+0.2, i+.1, str(v), color = 'blue', fontweight = 'bold')
    
plt.show()

# %%
# Komplain terbanyak adalah 'Blocked Driveaway'

# %%
# 10 kota dengan komplain terbanyak
city=df.groupby('City')['Complaint Type'].count().to_frame().sort_values('Complaint Type',ascending=False).reset_index()
city10 = city.iloc[:10]

fig = plt.figure(figsize = (8,8))
plt.pie(city10['Complaint Type'], labels = city10['City'], autopct = '%0.1f%%', radius = 1, shadow = True, 
           textprops = {'fontsize' : 15, 'color' : 'black'});

plt.show()
city10
# Out:
#             City  Complaint Type
# 0       BROOKLYN           98306
# 1       NEW YORK           65993
# 2          BRONX           40701
# 3  STATEN ISLAND           12343
# 4        JAMAICA            7296
# 5        ASTORIA            6330
# 6       FLUSHING            5971
# 7      RIDGEWOOD            5163
# 8         CORONA            4295
# 9       WOODSIDE            3544

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'])
df['Closed Date'] = pd.to_datetime(df['Closed Date'])
df['Closing Time'] = df['Closed Date'] - df['Created Date']
df['Closing Time (minutes)'] = df['Closing Time'].dt.seconds/60
df.groupby(['Status'])['Closing Time (minutes)'].mean().to_frame()
# Out:
#           Closing Time (minutes)
# Status
# Assigned              485.207051
# Closed                235.742654
# Draft                 350.983333
# Open                  231.619444

# %%
#lokasi dan persentase kejadian
fig = plt.figure(figsize = (20,15))

plt.style.use('seaborn-pastel')
location = ((df['Location Type'].value_counts(normalize = True))*100).to_frame()
plt. grid()
plt.bar(location.index, location['Location Type'], width = 0.4)
plt.xticks(rotation = 65, size = 12)
plt.yticks(range(0,90,4), size = 12)
plt.ylabel("Persentase Kejadian", size = 15);
